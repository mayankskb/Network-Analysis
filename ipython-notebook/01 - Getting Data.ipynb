# %% [markdown]
# #  Scraping of Data
#
# <b> Here we are scraping the data from the meetup.com using the REST API </b>

# %% [markdown]
# ** Importing Requisites **

# %%
import requests
import pandas as pd
from json import loads
from time import sleep

# %% [markdown]
# ** Defining base stuff **

# %%
api_token = '5d1e1736057567d21d18111b3e363c'

api_url_base = 'https://api.meetup.com/'

# %%
url = '{0}/find/groups'.format(api_url_base)


headers = {
    'sign' : 'true',
    'key' : api_token,
    'zip' : '411030'    
}

# %%
def get_meetup_group_data(url, headers, filename = None):
    
    # Making a get request for data
    resp = requests.get(url, params = headers)
    
    status = resp.status_code
    
    # Printing status
    print('Response Code : {}'.format(status))
    
    # check that we either got a successful response (200) or a previously retrieved, but still valid response (304)
    if status == 200:
        print('Successful.. ')
        
    else :
        print('Unsuccessful')
        exit(1)
    
    response = resp.json()
    
    cols = ('group_id', 'group_name', 'num_members', 'category_id', 
            'category_name', 'organizer_id', 'group_urlname')
    meetup_group = pd.DataFrame(columns = cols)
        
    response = resp.json()
    
    if len(response) > 0:
        
        
        try:
            for g in response:
                s = pd.Series((g['id'], g['name'], g['members'], g['category']['id'], 
                               g['category']['name'], g['organizer']['id'], g['urlname']),
                               index=cols)
                meetup_group = meetup_group.append(s, ignore_index=True)
        
        except KeyError as exc:
                print(g['name'], exc)
        
        # Sleep briefly so that API doesn't get overwhelmed
        sleep(0.2)

    meetup_group = meetup_group.astype({'group_id': int, 'organizer_id': int, 'category_id': int, 'num_members': int})
    
    writepath = '../dataFiles/{}'.format(filename)
    
    # Write to computer
    if filename:
        meetup_group.to_csv(writepath, encoding='utf-8', index = False) 

    return meetup_group

# %%
meetup_group = get_meetup_group_data(url, headers, filename = 'meetup_group.csv')
# Out:
# Response Code : 200
# Successful..

# %%
meetup_group.head()
# Out:
#    group_id                              group_name  num_members  category_id  \
# 0  19394496              Pune Developer's Community         4340           34
# 1   4387912  Google Developer Group Pune : GDG Pune         6163           34
# 2   3730702                        ExpertTalks Pune         6064           34
# 3  18446215      Internet Of Things, Pune (IoTPune)         6804            6
# 4  25835616                ThoughtWorks Pune Events         1261           34
#
#           category_name  organizer_id                    group_urlname
# 0                  Tech     182849219        Pune-Developers-Community
# 1                  Tech      25480862                         Pune-GDG
# 2                  Tech      14196782                expert-talks-Pune
# 3  Education & Learning     111363232  Internet-Of-Things-Pune-IoTPune
# 4                  Tech     235949519      ThoughtWorks-GeekNight-Pune

# %%
def get_events(url, headers, date_filter_str = None, urlname = None):
    
    response = requests.get(url, params = headers)
    if response.status_code == 410:
        raise ValueError('Group not accessible.')
    if len(response.json()) == 0:
        print('No event for this till now')
        return
    
    events_df = pd.DataFrame.from_dict(response.json())
    events_df.time = pd.to_datetime(events_df.time, unit='ms')
    events_df['group_urlname'] = urlname
    events_df['event_id'] = events_df['id']
    
    if date_filter_str:
        events_df = events_df.loc[events_df.time > pd.to_datetime(date_filter_str)]
        
    return events_df

# %%
headers = {
    'sign' : 'true',
    'key' : api_token,
    'page' : '200',
    'status' : 'past'
}

# %%
cols = ['event_id', 'name', 'status', 'time', 'yes_rsvp_count', 'group_urlname']
events = pd.DataFrame(columns = cols)

for gp_url in meetup_group.group_urlname:
    
    print('Getting Data for {}'.format(gp_url))
    url = api_url_base + '/{}/events'.format(gp_url)
    
    val = get_events(url = url, headers = headers, urlname = gp_url, date_filter_str='2017-01-01')
    
    # Concatenating the fetched data to events dataframe
    frame = [events, val]
    events = pd.concat(frame, ignore_index=True)
          
events = events[cols]
events.to_csv('../dataFiles/events.csv', index=False)
# Out:
# Getting Data for Pune-Developers-Community
# Getting Data for Pune-GDG
# Getting Data for expert-talks-Pune
# Getting Data for Internet-Of-Things-Pune-IoTPune
# Getting Data for ThoughtWorks-GeekNight-Pune
# Getting Data for Pune-Mobile-Developers
# Getting Data for urclubpune
# Getting Data for NASSCOM-10000-Startups-Pune
# Getting Data for discuss-agile-network-pune
# Getting Data for Machine-Learning-Pune
# Getting Data for Data-Science-and-Machine-Learning
# Getting Data for Pune-Travel-Club
# Getting Data for Pune-Artificial-Intelligence-Deep-Learning
# Getting Data for 91springboard-Pune
# Getting Data for sspune
# Getting Data for Ansible-Pune
# Getting Data for SkewCode2
# Getting Data for Pune-WordPress-Knowledge-Exchange
# Getting Data for BlueRidge-IT-meetup
# Getting Data for Pune-Footballers-Club
# Getting Data for meetup-group-mBrnrixQ
# Getting Data for Pune-Stock-Investors-Meetup
# Getting Data for Pune-Spring-Meetup
# Getting Data for TechnoWise
# Getting Data for meetup-group-ScPJDxDX
# Getting Data for ReactJS-and-Friends
# Getting Data for Online-Business-Marketing-For-Startups-and-Entrepreneurs
# Getting Data for Neuro-Talent-Mapping
# No event for this till now
# Getting Data for PuneRailsMeetup
# Getting Data for Pune-Fiction-Meetup
# Getting Data for Write-here-Write-now-Pune-Writers-Group
# Getting Data for PyData-Pune
# Getting Data for NukkadCafe
# Getting Data for datascience-iotpune
# No event for this till now
# Getting Data for job-business-opportunities
# Getting Data for THE-DAFTAR-COWORKING
# Getting Data for START-UP-WITH-START-UPS
# Getting Data for Pune-Agile-Thought-Leaders
# Getting Data for NoSQL-Pune-Community
# No event for this till now
# Getting Data for meetup-group-sshaMjYq
# Getting Data for Pune-Strategy-Board-Games
# Getting Data for Pune-Business-Agility-Meetup
# No event for this till now
# Getting Data for Pune-Decentralization-Meetup
# Getting Data for SAHYADRI-ADVENTURE-CLUB
# Getting Data for Pagdandi-The-Rough-Road
# Getting Data for Kubernetes-Pune
# Getting Data for Agile-Practitioners-Group-of-India-APGI
# Getting Data for Pune-AI-Geeks
# Getting Data for Pune-Entrepreneurs-Innovators
# Getting Data for Pune-Spoken-Word-Meetup
# Getting Data for IoT-Electronics-Pune
# Getting Data for We-love-AWS-CloudFormation
# Getting Data for India-Big-Data-Analytics-Meetup
# Getting Data for Global-Innovators-Entrepreneurs-Conclave
# No event for this till now
# Getting Data for Spark-Scala-Pune
# Getting Data for artandnow
# Getting Data for Pune-Big-Data-Analytics-Meetup
# Getting Data for Pune-Agile-Professionals
# Getting Data for Golang-Pune
# Getting Data for PlayScrum-Pune
# Getting Data for Pune-Big-Data-Conference-Group
# Getting Data for GroupArtCircle
# Getting Data for PuneBookLovers
# Getting Data for puneuitalks
# Getting Data for Bitcoin-cash-pune
# No event for this till now
# Getting Data for Distributed-Systems-Meetup
# Getting Data for Transform-Agile-Failures-to-Success
# Getting Data for PuneHikers
# Getting Data for Pune-Blockchain-Meetup-2018
# Getting Data for OLED101
# Getting Data for Pune-Robotics-Process-Automation
# Getting Data for The-Pune-Book-Readers-Club
# Getting Data for Pune-over-40-Meetup
# Getting Data for Equity-Stock-Market-Professional-Traders-Whatsapp-Group
# Getting Data for Pune-Value-Investors-Meetup
# Getting Data for West-Pune
# Getting Data for Internet-of-everything-Pune
# Getting Data for PythonPune
# Getting Data for reserved-bit
# Getting Data for meetup-group-HCIjJUuf
# Getting Data for TMCPCentral
# Getting Data for Pune-Weekend-Events
# Getting Data for pixean-pune
# Getting Data for All-India-Oracle-Users-Group-Pune-Chapter
# Getting Data for Pune-Meditation-Meetup
# No event for this till now
# Getting Data for Pub-Quizzes-in-Pune
# Getting Data for Social-Media-Marketing-Users
# Getting Data for Toastmasters-Club-of-Pune-South-East
# Getting Data for Pune-Backpackers-n-City-Freaks
# Getting Data for Technical-Analysis-and-Investment
# Getting Data for Pimpri-Toastmasters-Club
# Getting Data for Pune-Free-Swatantra-Libre-Freedom-Software-Meetup
# Getting Data for Pune-Personality-development-pratical-Meetup
# Getting Data for Kizomba-Workshop-in-Pune-Meetup
# Getting Data for Pune-Public-Speaking-Club
# Getting Data for PCMC-Morning-Meditation-Wakad
# Getting Data for Toastmasters-Club-Of-Pune-West
# Getting Data for TechNxt
# Getting Data for Startup-Gears-Pune
# Getting Data for sworkpune
# Getting Data for Pune-Chess-Meetup
# Getting Data for Software-Developer-in-testing
# Getting Data for Pixean-Aven-Pune
# Getting Data for Pune-Magento-Meetup
# Getting Data for Women-Tech-Heroes-Pune
# Getting Data for meetup-group-RXJhzWOL
# Getting Data for Indian-Aviators
# Getting Data for Success-Mantra
# Getting Data for Young-Internationals-in-Pune
# Getting Data for Pune-Network-Security-Meetup
# Getting Data for PuneAdventure
# Getting Data for EaseIndiaTravel
# Getting Data for PHPReboot
# Getting Data for openIoThinkers
# Getting Data for kalyaniNagar-Investor-Entrepreneurs-Meetup
# Getting Data for Affiliate-Marketing-Pro
# Getting Data for The5thGearRidersPune
# Getting Data for Pune-Anime-Community
# Getting Data for agile-30-pune
# Getting Data for Puneri-Jobs
# Getting Data for Creative-Pad-Workshops-Pune
# Getting Data for Bharti-Vidyapeeth-Jogguars
# Getting Data for A-friend-in-need-is-a-friend-indeed
# Getting Data for Toastmasters-Club-of-Pune-North-East
# Getting Data for TechJam-Pune
# Getting Data for tahaanefforts
# Getting Data for Pune-Travel-Buddies-International-Domestic
# Getting Data for Elixir-Pune
# Getting Data for Project-Managers-Club-of-Pune
# Getting Data for OdiaPune-Meetup
# Getting Data for AnalyticsWay-Training-Consulting-Jobs-DataScience-ML-AI
# No event for this till now
# Getting Data for J4E-EPL-Entrepreneurs-Breakfast-Meeting
# Getting Data for Bnpcafe-Startup-for-all-Professionals
# Getting Data for lady-rockers
# Getting Data for Pune-Hobby-Entreprenuers
# Getting Data for Pure-Experiences-Online-Satsang
# Getting Data for Pune-Debian-Users-Group
# Getting Data for meetup-group-Roadnottaken
# Getting Data for Roaming-Clan-Pune-and-International
# Getting Data for Pune-Mood-Disorders-Support-Group
# No event for this till now
# Getting Data for Trekking-Biking-Cycling-Adventure-Meetup-Pune
# Getting Data for Unsullied-Bike-ride-Exploring-West-Bengal-and-Nepal
# No event for this till now
# Getting Data for Pune-Outdoors-Towards-Himalayas
# No event for this till now
# Getting Data for meetup-group-MeNKhMim
# Getting Data for YourSarthi
# Getting Data for Vizitech-Blockchain-Meetup
# Getting Data for escapadeoutdoors
# Getting Data for Pune-Poker-Meetup-cashhh
# Getting Data for Sutra-Power-of-Subconscious
# Getting Data for Relationship-Mantras
# Getting Data for meetup-group-wAGZmrcP
# Getting Data for HindiKavitaPune
# Getting Data for PuneDigitalMarketers
# Getting Data for Startup-Grind-Pune
# Getting Data for Pune-Positive-Thinking-Meetup
# Getting Data for Pune-Single-Parents-Network
# Getting Data for Happy-Mates-Pune
# Getting Data for Buddhas-teachings
# Getting Data for Punelesbians
# No event for this till now
# Getting Data for Pune-single-parents-meet
# No event for this till now
# Getting Data for 1000Pune-Walking-Meetup
# No event for this till now
# Getting Data for Pune-Dhamal-Masti-Group
# Getting Data for Startups-Enthusiasts-Entrepreneurs-Meetup
# Getting Data for Pune-Hiking-Meetup
# Getting Data for Pune-Cuban-Music-Meetup
# Getting Data for Weekend-Fun-Club
# Getting Data for Pune-Capoeira-Meetup
# Getting Data for Pune-Socialise-Meetup
# Getting Data for punephoto
# Getting Data for 90b2615f-a01f-483d-ba5a-79ee7c1b4a60
# Getting Data for Lost-The-Plot-Punes-first-rooftop-cinema-bar
# Getting Data for Meditation-with-Shri-ShivaBalayogi-Pune
# Getting Data for Femme-Fiesta-Club-Monthly-Meet
# Getting Data for Pune-Crafties
# No event for this till now
# Getting Data for Cloud-computing-aws-and-scalability
# Getting Data for Pune-DAILY-MORNING-SPORTS-AND-EXERCISE-6-AM-TO-8-AM
# No event for this till now
# Getting Data for AmazonAWS-India
# Getting Data for Pune-40-plus-couples-with-school-going-kids-Meetup
# Getting Data for College-Buddies-Ready-for-Travel-Together
# Getting Data for Career10xpro
# Getting Data for Pune-Inspired-Tribe
# Getting Data for Pune-Poker-Stars-Meetup
# Getting Data for Pune-CAD-CAM-Meetup
# Getting Data for SelfGrowthAndLifeSuccess
# Getting Data for Unlimited-SKYE-Meetup
# No event for this till now
# Getting Data for Home-UnSchoolers
# Getting Data for Natural-Building-and-Village-Tour
# Getting Data for Intro-of-New-people-in-town
# Getting Data for Couples-Meetup-pune
# Getting Data for Lean-Coffee-Pune
# Getting Data for Pune-Dance-learners
# No event for this till now
# Getting Data for Pune-Drinking-Meetup-at-cheap-rate-but-in-lavish-club
# Getting Data for PuneDigitalMarketingConnection
# Getting Data for Pune-Microsoft-Azure-Meetup
# No event for this till now
# Getting Data for stumble-on-success-executive-coaching-prog-for-entrepreneurs
# No event for this till now
# Getting Data for Pune-Amazon-RedShift-Group
# No event for this till now
# Getting Data for Pune-Social-Media-Management-Meetup
# No event for this till now
# Getting Data for Pune-Heroku-Meetup
# Getting Data for Pune-Animation-Meetup
# Getting Data for Investment-Business-Opportunities-in-India

# %%
events.head()
# Out:
#     event_id                                          name status  \
# 0  236723955  Develop your very own Alexa skill in an hour   past
# 1  236770319                                    Clean code   past
# 2  237491427   Google Cloud Next'17 Extended - Pune by PDC   past
# 3  238211889                               Insights of NLP   past
# 4  238212161                         Scaling ElasticSearch   past
#
#                  time yes_rsvp_count              group_urlname
# 0 2017-01-14 04:30:00            101  Pune-Developers-Community
# 1 2017-02-11 04:30:00            172  Pune-Developers-Community
# 2 2017-03-18 04:30:00            127  Pune-Developers-Community
# 3 2017-03-25 04:30:00             91  Pune-Developers-Community
# 4 2017-04-22 04:30:00             74  Pune-Developers-Community

# %%
def get_event_rsvps(url, headers, group_urlname, event_id):
    
    '''Accepts a group urlname and event id, and returns a dataframe of RSVPs.'''
    
    response = requests.get(url, params = headers).json()
    try:
        member_list = [(group_urlname, event_id, mem['member']['id']) for mem in response]
        rsvp_df = pd.DataFrame(member_list, columns=['group_urlname', 'event_id', 'member_id'])

        return rsvp_df
    except:
        print(group_urlname, event_id)
        
        return

# %%
url = 'https://api.meetup.com/{}/events/{}/rsvps'

headers = {
    'sign' : 'true',
    'key' : api_token  
}

rsvp_df = pd.DataFrame(columns=['group_urlname', 'event_id', 'member_id'])

print("Fetching number of RSVP's For the events")
for index, event in events.iterrows():
    
    val = get_event_rsvps(url.format(event['group_urlname'], event['event_id']), headers, event['group_urlname'], event['event_id'])
    
    frame = [rsvp_df, val]
    rsvp_df = pd.concat(frame, ignore_index=True)
    
rsvp_df.to_csv('../dataFiles/rsvps.csv', index=False)
# Out:
# Fetching number of RSVP's For the events
# Agile-Practitioners-Group-of-India-APGI 236693424
# Agile-Practitioners-Group-of-India-APGI 240908380
# Agile-Practitioners-Group-of-India-APGI 243577244
# Agile-Practitioners-Group-of-India-APGI 243848931
# Agile-Practitioners-Group-of-India-APGI 245609189
# Agile-Practitioners-Group-of-India-APGI 246646599
# Agile-Practitioners-Group-of-India-APGI 246868175
# Agile-Practitioners-Group-of-India-APGI 247809675
# Agile-Practitioners-Group-of-India-APGI 249735935
# The-Pune-Book-Readers-Club 236637190
# The-Pune-Book-Readers-Club 237729215
# The-Pune-Book-Readers-Club 240342897
# The-Pune-Book-Readers-Club 240557913
# The-Pune-Book-Readers-Club 241304703
# The-Pune-Book-Readers-Club 243145687
# The-Pune-Book-Readers-Club 243626473
# The-Pune-Book-Readers-Club 243626523
# The-Pune-Book-Readers-Club 241741589
# The-Pune-Book-Readers-Club 245633159
# The-Pune-Book-Readers-Club 246513494
# The-Pune-Book-Readers-Club 247447716
# The-Pune-Book-Readers-Club 248504105
# The-Pune-Book-Readers-Club 248504068
# Pune-over-40-Meetup 236565000
# Pune-over-40-Meetup 236565074
# Pune-over-40-Meetup 240961717
# Pune-over-40-Meetup 241267472
# Pune-over-40-Meetup 241980483
# Pune-over-40-Meetup 242404425
# Pune-over-40-Meetup 244648479
# Pune-over-40-Meetup 246407442
# Pune-over-40-Meetup 246803279
# Pune-over-40-Meetup 247273925
# Pune-over-40-Meetup 249893027
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywcbkc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywdbgc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywfbpc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywgblc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywhbjc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywjbnc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywkblc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywlbhc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywmbmc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywnbkc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywpbgc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlywqbmc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlyxcbjc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlyxdbfc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlyxfbnc
# Equity-Stock-Market-Professional-Traders-Whatsapp-Group ddmnxlyxgbkc
# Pune-Backpackers-n-City-Freaks 244170792
# Pune-Backpackers-n-City-Freaks 244170833
# Pune-Backpackers-n-City-Freaks 244025991
# Pune-Backpackers-n-City-Freaks ffsrznywpbhc
# Pune-Backpackers-n-City-Freaks khsrznywpbhc
# Pune-Backpackers-n-City-Freaks hcsrznywpbhc
# Pune-Backpackers-n-City-Freaks 244051818
# Pune-Backpackers-n-City-Freaks 245016458
# Pune-Backpackers-n-City-Freaks ffsrznywqbdb
# Pune-Backpackers-n-City-Freaks khsrznywqbdb
# Pune-Backpackers-n-City-Freaks hcsrznywqbdb
# Pune-Backpackers-n-City-Freaks ffsrznywqbmb
# Pune-Backpackers-n-City-Freaks khsrznywqbmb
# Pune-Backpackers-n-City-Freaks hcsrznywqbmb
# Pune-Backpackers-n-City-Freaks ffsrznywqbvb
# Pune-Backpackers-n-City-Freaks khsrznywqbvb
# Pune-Backpackers-n-City-Freaks hcsrznywqbvb
# Pune-Backpackers-n-City-Freaks 245306022
# Pune-Backpackers-n-City-Freaks ffsrznywqbfc
# Pune-Backpackers-n-City-Freaks khsrznywqbfc
# Pune-Backpackers-n-City-Freaks hcsrznywqbfc
# Pune-Backpackers-n-City-Freaks 247136026
# Pune-Backpackers-n-City-Freaks 246961460
# Pune-Backpackers-n-City-Freaks 246475150
# Pune-Backpackers-n-City-Freaks 248048564
# Pune-Backpackers-n-City-Freaks 247673652
# Pune-Backpackers-n-City-Freaks 248810833
# Pune-Backpackers-n-City-Freaks 249421673
# Pune-Backpackers-n-City-Freaks 249448703
# Pune-Backpackers-n-City-Freaks 248774437
# Young-Internationals-in-Pune 236435465
# Young-Internationals-in-Pune 237261872
# Young-Internationals-in-Pune 237628807
# Young-Internationals-in-Pune 237697783
# Young-Internationals-in-Pune 237606902
# Young-Internationals-in-Pune 238143605
# Young-Internationals-in-Pune 238080017
# Young-Internationals-in-Pune 238921060
# Young-Internationals-in-Pune 238381448
# Young-Internationals-in-Pune 239729972
# Young-Internationals-in-Pune 240387872
# Young-Internationals-in-Pune 240475052
# Young-Internationals-in-Pune 242086855
# Young-Internationals-in-Pune 242487767
# Young-Internationals-in-Pune 242615736
# Young-Internationals-in-Pune 243458535
# Young-Internationals-in-Pune 243463101
# Young-Internationals-in-Pune 243946630
# Young-Internationals-in-Pune 244196925
# Young-Internationals-in-Pune 244475640
# Young-Internationals-in-Pune 245023654
# Young-Internationals-in-Pune 245938648
# Young-Internationals-in-Pune 246089291
# Young-Internationals-in-Pune 247116348
# Young-Internationals-in-Pune 247736248
# Young-Internationals-in-Pune 247736475
# Young-Internationals-in-Pune 247989646
# Young-Internationals-in-Pune 249739629
# Young-Internationals-in-Pune 250242423
# Affiliate-Marketing-Pro 249291729
# lady-rockers 238828309
# lady-rockers 239164216
# lady-rockers 241821730
# lady-rockers 241824341
# lady-rockers 242438259
# lady-rockers 242957838
# lady-rockers 243119881
# lady-rockers 243681767
# lady-rockers 244126361
# lady-rockers 245529887
# lady-rockers 246410572
# lady-rockers hzvrdpyxcbqb
# lady-rockers hzvrdpyxcbzb
# lady-rockers 246937222
# lady-rockers 247035321
# lady-rockers 247036508
# lady-rockers 247780442
# lady-rockers kcrflpyxfbmb
# lady-rockers 248745191
# lady-rockers dgbwlpyxfbfc
# lady-rockers kkbwlpyxfbnc
# lady-rockers kkbwlpyxgbjb
# lady-rockers 249911581
# Pune-Poker-Meetup-cashhh hlzdvlywcbcb
# Pune-Single-Parents-Network 249151109
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 237066376
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 239293583
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 240137587
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 239563047
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 240985000
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 241769407
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 242376266
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 242869139
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 243296247
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 243281380
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 243850968
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 244054002
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 243850939
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 244023610
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 244053944
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 244054155
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 244023623
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 244054230
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 246443765
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 246601018
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 246866758
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 247275986
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 248917465
# 90b2615f-a01f-483d-ba5a-79ee7c1b4a60 249666672
# Pune-Inspired-Tribe 237519148
# Pune-Inspired-Tribe 237749079
# Pune-Inspired-Tribe 237749359
# Pune-Inspired-Tribe 238209465
# Pune-Inspired-Tribe 239628511
# Pune-Inspired-Tribe 240113767
# Pune-Inspired-Tribe 241036617
# Pune-Inspired-Tribe 247577956
# Pune-Inspired-Tribe 248186327
# Pune-Inspired-Tribe 248427708
# Pune-Inspired-Tribe 249125497
# Pune-Poker-Stars-Meetup nlzdvlywcbcb
# Pune-Poker-Stars-Meetup bjzdvlywcbfb
# Pune-Poker-Stars-Meetup bjzdvlywcbhb
# Pune-Poker-Stars-Meetup bjzdvlywcbkb
# Couples-Meetup-pune 244835982
# Couples-Meetup-pune 245454623
# Couples-Meetup-pune 246972835
# Couples-Meetup-pune 249605767

# %%
unique_members = rsvp_df.member_id.unique()

# %%
def get_member_details(url, header, mem_id):
    '''Accepts a member id, and returns a dataframe of metadata information.'''
    
    response = requests.get(url, params = headers).json()
    try:
        member_detail = {'member_id':mem_id, 'name':response['name'], 'city' : response['city'],
                       'visited' : response['visited'], 'lon' : response['lon'], 'lat' : response['lat']}
        return member_detail
    except:
        print('Problem in getting user details from API')
        return

# %%
url = api_url_base + '2/member/{}'
header = {
    'sign' : 'true',
    'key' : api_token,
}

mem_df = pd.DataFrame(columns=['member_id', 'name', 'city', 'visited', 'lon', 'lat'])
for mem_id in unique_members:
    val = pd.DataFrame([get_member_details(url.format(mem_id), header, mem_id)])
    
    frame = [mem_df, val]
    mem_df = pd.concat(frame, ignore_index=True)
    
mem_df.to_csv('../dataFiles/members.csv', index=False)
